# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap="Greens")
plt.show()

# %%
X2 = X_scaled[:, :2]
X_train2, X_test2, y_train2, y_test2 = train_test_split(
    X2, y, test_size=0.2, random_state=42
)

gnb.fit(X_train2, y_train2)
# Out:
# GaussianNB()

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)   # X_train has 4 features

y_pred = gnb.predict(X_test)

# %%
print("Model expects:", gnb.n_features_in_)
print("Input has:", X_test.shape[1])
# Out:
# Model expects: 4
# Input has: 4

# %%
probs = gnb.predict_proba(X_test)
print(probs[:5])
# Out:
# [[5.97322611e-090 9.95635768e-001 4.36423247e-003]
#  [1.00000000e+000 4.96157683e-014 6.54921950e-021]
#  [7.31861098e-290 4.92947289e-012 1.00000000e+000]
#  [2.81838335e-094 9.77593560e-001 2.24064404e-002]
#  [1.13876385e-105 8.70022604e-001 1.29977396e-001]]

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
print("Logistic Accuracy:", accuracy_score(y_test, lr.predict(X_test)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 lr = LogisticRegression()
#       2 lr.fit(X_train, y_train)
#       3 print("Logistic Accuracy:", accuracy_score(y_test, lr.predict(X_test)))
#
# NameError: name 'LogisticRegression' is not defined
